# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A bat and a ball cost $1.10 together. The bat costs $1.00 more than the ball. How much does the ball cost?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let the cost of the ball be \( x \) dollars.
#
# Since the bat costs $1.00 more than the ball, the cost of the bat is \( x + 1.00 \) dollars.
#
# Together, they cost $1.10:
# \[
# x + (x + 1.00) = 1.10
# \]
# \[
# 2x + 1.00 = 1.10
# \]
# \[
# 2x = 1.10 - 1.00 = 0.10
# \]
# \[
# x = \frac{0.10}{2} = 0.05
# \]
#
# **Answer:** The ball costs **5 cents**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let the cost of the ball be \( x \) dollars.
#
# Since the bat costs $1.00 more than the ball, the cost of the bat is \( x + 1.00 \) dollars.
#
# Together, they cost $1.10:
# \[
# x + (x + 1.00) = 1.10
# \]
# \[
# 2x + 1.00 = 1.10
# \]
# \[
# 2x = 1.10 - 1.00 = 0.10
# \]
# \[
# x = \frac{0.10}{2} = 0.05
# \]
#
# **Answer:** The ball costs **5 cents**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "What area is most ready for Agentic AI opportunities"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
display(Markdown(business_idea))

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": "What is a pain point in this industry: " + business_idea + ". that Agentic AI can solve"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

problem = response.choices[0].message.content
display(Markdown(problem))

messages = [{"role": "user", "content": "How would you solve this problem: " + problem + ". In this industry: " + business_idea + ". With agentic AI?"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solution = response.choices[0].message.content
display(Markdown(solution))
# Out:
# The area most ready for Agentic AI opportunities typically involves sectors where AI systems can take autonomous, goal-directed actions with significant impact, guided by clear objectives and structured environments. As of now, some of the most promising areas include:
#
# 1. **Autonomous Vehicles and Robotics**
#    - Self-driving cars, drones, and delivery robots benefit from agentic AI that perceives, plans, and acts within dynamic real-world environments.
#    - These systems already integrate perception, decision-making, and control in real-time.
#
# 2. **Enterprise Process Automation**
#    - Intelligent agents that manage workflows, optimize supply chains, handle customer service via chatbots, and perform knowledge work tasks.
#    - Agentic AI here can autonomously interact with multiple systems and humans to achieve business goals.
#
# 3. **Personal Digital Assistants and Productivity Tools**
#    - AI agents that proactively schedule meetings, manage emails, prioritize tasks, or provide personalized recommendations.
#    - These applications leverage user data and context to act on behalf of users.
#
# 4. **Cybersecurity**
#    - AI agents that detect, prevent, and respond to threats autonomously by monitoring networks, identifying anomalies, and taking mitigation actions.
#
# 5. **Healthcare and Personalized Medicine**
#    - AI that assists in diagnostics, treatment planning, and patient monitoring by autonomously integrating diverse clinical data streams.
#
# Among these, **enterprise process automation** and **personal digital assistants** arguably represent the most immediately ready and scalable domains for agentic AI deployment because they operate in structured digital environments with clear objectives and fewer safety or regulatory constraints compared to physical-world applications like autonomous vehicles.
#
# ### Summary
# **Enterprise automation and personal digital assistants** are currently the areas most ready for agentic AI opportunities due to their clear task definitions, existing digital infrastructure, and high demand for autonomous, goal-driven AI agents.
#
# If you have a particular vertical or application in mind, I can provide a more tailored analysis!
# A key pain point in the **enterprise process automation** industry that Agentic AI can solve is **the complexity and fragmentation of workflows across multiple systems and stakeholders**.
#
# ### Explanation:
# Many enterprises struggle with inefficient, error-prone processes because workflows involve many different software platforms, human teams, and data sources that often don’t integrate smoothly. This leads to:
#
# - Manual handoffs causing delays and mistakes
# - Lack of end-to-end visibility into process status
# - Difficulty in dynamically adapting workflows to changing conditions or priorities
# - Bottlenecks due to limited human capacity to monitor and coordinate all steps
#
# ### How Agentic AI can address this pain point:
# Agentic AI systems are capable of autonomously navigating and orchestrating complex workflows by interacting with multiple software tools and humans, making goal-directed decisions in real-time. This means:
#
# - Autonomous workflow management that reduces manual coordination
# - Real-time problem detection and resolution within processes
# - Dynamic reprioritization and optimization based on current business context
# - Improved productivity through seamless cross-system automation
#
# Thus, agentic AI can transform fragmented enterprise processes into agile, self-managing workflows, delivering significant efficiency gains and reducing operational risk.
# Certainly! Here’s how you could solve or approach the key pain point in **enterprise process automation** — the complexity and fragmentation of workflows across multiple systems and stakeholders — using **agentic AI**:
#
# ---
#
# ## Problem Recap
#
# Enterprise automation struggles because workflows span many disconnected systems and involve multiple human teams. This results in:
#
# - Manual handoffs and errors
# - Poor visibility and control
# - Rigidity in adapting to changes
# - Bottlenecks from limited human oversight
#
# ---
#
# ## Agentic AI-based Solution Approach
#
# ### 1. **Unified Workflow Orchestration Layer**
#
# Build an agentic AI system that acts as an intelligent orchestration layer spanning all relevant platforms and stakeholders.
#
# - **Integration**: Use APIs, RPA (robotic process automation) connectors, and event listeners to hook into all workflow systems and data sources.
# - **Holistic View**: The agent maintains an up-to-date model of the entire process state and each step’s context.
#
# ### 2. **Autonomous Coordination & Decision-Making**
#
# Equip the AI agent with goal-directed autonomy:
#
# - **Task Delegation**: Automatically assign tasks to appropriate systems or humans based on availability, skill, and priority.
# - **Dynamic Adaptation**: Detect delays, bottlenecks, or exceptions in real time; reorder or reallocate tasks dynamically.
#
# ### 3. **Real-Time Monitoring and Issue Resolution**
#
# - Continuously monitor process metrics and health indicators using AI-powered anomaly detection.
# - Upon detecting deviations (e.g., overdue approvals, data inconsistencies), the agent takes corrective actions autonomously or escalates intelligently.
#
# ### 4. **End-to-End Visibility and Transparent Reporting**
#
# - Provide dashboards and notifications that give stakeholders real-time insights into process status and predicted outcomes.
# - Use explainable AI techniques so decisions by the autonomous agent are interpretable and auditable.
#
# ### 5. **Continuous Learning and Optimization**
#
# - Incorporate reinforcement learning or feedback loops so the agent improves process efficiency over time.
# - Optimize based on goals such as minimizing cycle time, cost, or error rates.
#
# ---
#
# ## Practical Implementation Steps
#
# **Step 1:** Map out all interconnected systems, stakeholders, and workflows you want to integrate.
#
# **Step 2:** Design a knowledge graph or process model that the agentic AI can reference to understand workflows.
#
# **Step 3:** Develop connectors (APIs, RPA scripts) to integrate the agent with each system.
#
# **Step 4:** Train or program the agentic AI’s decision-making engine to handle workflow coordination, prioritization, exception handling, and dynamic replanning.
#
# **Step 5:** Pilot in a controlled sub-process to validate autonomous workflow management, monitoring, and reporting.
#
# **Step 6:** Expand incrementally, incorporating feedback and refining agent autonomy and learning mechanisms.
#
# ---
#
# ## Why Agentic AI Is Ideal Here
#
# - **Goal-Directed Autonomy:** Can act proactively and adaptively without waiting for human input for every decision.
# - **Cross-System Awareness:** Maintains end-to-end process state across fragmented platforms.
# - **Dynamic Decision-Making:** Reacts to changing priorities, bottlenecks, and exceptions in real-time.
# - **Human-Agent Collaboration:** Seamlessly involves humans when needed, escalating or requesting input only when required.
#
# ---
#
# ## Example Scenarios
#
# - **Supply Chain Automation:** Agentic AI detects supplier delays, reroutes orders, and notifies procurement automatically.
# - **Customer Service Workflow:** AI orchestrates ticket triage, routes complex cases to humans, and escalates SLA breaches preemptively.
# - **HR Onboarding:** Agent coordinates paperwork, training assignments, and IT provisioning autonomously, ensuring smooth new hire experience.
#
# ---
#
# ## Summary
#
# By deploying agentic AI as an intelligent orchestrator across fragmented enterprise systems, enterprises can transform clunky, manual, multi-stakeholder workflows into agile, autonomous processes. This leads to:
#
# - Reduced errors and delays
# - Increased transparency and control
# - Greater adaptability to dynamic business needs
# - Enhanced productivity and risk mitigation
#
# ---
#
# If you want, I can help you draft a more detailed architecture, technology stack, or pilot plan for deploying agentic AI in a specific enterprise domain!
